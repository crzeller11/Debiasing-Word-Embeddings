# %% [markdown]
# # Debiasing Word Embeddings  - Senior Comps
# ## Data Analysis
# For personal reference:
# * [Jupyter Notebook Shortcuts](http://maxmelnick.com/2016/04/19/python-beginner-tips-and-tricks.html)
# * [Markdown Guide](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)

# %%
# IMPORTS
import pandas as pd

# %%
raw_data = pd.read_csv('results.csv')
gender_directions = ['IMPLIED', 'LITERAL', 'PRONOUNS']
models = ['MODEL 1', 'MODEL 2']
adjective_data = raw_data.iloc[::2]
occupation_data = raw_data.iloc[1::2]


def check_bias_minimization(word_data):
    for label in gender_directions:
        print(label)
        column_data = word_data[[label]]
        for i in range(2):
            print('\t' + models[i])
            if column_data.iloc[i, 0] > column_data.iloc[i + 2, 0]:
                print('\t\t' + 'BIAS REDUCED')
            else:
                print('\t\t' + 'BIAS NOT REDUCED')

print('--- ADJECTIVES ---')
check_bias_minimization(adjective_data)
print()
print('--- OCCUPATIONS ---')
check_bias_minimization(occupation_data)
# Out:
# --- ADJECTIVES ---
# IMPLIED
# 	MODEL 1
# 		BIAS REDUCED
# 	MODEL 2
# 		BIAS NOT REDUCED
# LITERAL
# 	MODEL 1
# 		BIAS NOT REDUCED
# 	MODEL 2
# 		BIAS NOT REDUCED
# PRONOUNS
# 	MODEL 1
# 		BIAS REDUCED
# 	MODEL 2
# 		BIAS REDUCED
#
# --- OCCUPATIONS ---
# IMPLIED
# 	MODEL 1
# 		BIAS REDUCED
# 	MODEL 2
# 		BIAS NOT REDUCED
# LITERAL
# 	MODEL 1
# 		BIAS NOT REDUCED
# 	MODEL 2
# 		BIAS NOT REDUCED
# PRONOUNS
# 	MODEL 1
# 		BIAS NOT REDUCED
# 	MODEL 2
# 		BIAS NOT REDUCED

# %%
'''
for direction in gender_directions:
    df = pd.DataFrame({'Direct Bias': MODEL1.iloc[::2][[direction]].iloc[0,0]}, index=columns)
    df.plot.bar(rot=0)
'''

# %%
# PLOT RESULTS:
from bokeh.io import show, output_notebook, push_notebook
from bokeh.plotting import figure
from bokeh.layouts import gridplot

output_notebook()

# adjectives, occupations
MODEL1 = [raw_data.iloc[0:4].iloc[::2], raw_data.iloc[0:4].iloc[1::2]] 
MODEL2 = [raw_data.iloc[4:8].iloc[::2], raw_data.iloc[4:8].iloc[1::2]] 

columns = ['Original Model', 'Retrained Model']
'''
def get_model_plots(model_data):
    model_plts = []
    for i in range(len(model_data)):
        word_type_mdls = []
        for direction in gender_directions:
            p = figure(plot_width=250, plot_height=250, title=None)
            p.vbar(x=columns, top=model_data[i][[direction]].iloc[0,0], width=0.5) # Can't be 0,0 because it excludes a value
            word_type_mdls.append(p)
        model_plts.append(word_type_mdls)
    return model_plts


model_1_plots = get_model_plots(MODEL1)
model_2_plots = get_model_plots(MODEL2)
grid = gridplot(model_1_plots)
handle = show(grid, notebook_handle=True) # why is this opening another tab
push_notebook(handle=handle)


'''
# BASE CASE: TRY TO GET THIS WORKING FIRST
p = figure(plot_width=250, plot_height=250, title=None)
p.vbar(x=columns, top=MODEL1[0][['LITERAL']].values.T.tolist()[0], width=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3f174177-65a6-4357-a1c2-9d7a1f32adce">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8fc0da50-05ef-457a-af00-86ec96b48c34"></div>
# </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-ad28af3822cb> in <module>()
#      36 p.vbar(x=columns, top=MODEL1[0][['LITERAL']].values.T.tolist()[0], width=0.5)
#      37 handle = show(p, notebook_handle=True)
# ---> 38 push_notebook(handle=handle)
#      39
#      40
#
# /anaconda3/lib/python3.6/site-packages/bokeh/util/api.py in wrapper(*args, **kw)
#     188         @wraps(obj)
#     189         def wrapper(*args, **kw):
# --> 190             return obj(*args, **kw)
#     191
#     192         wrapper.__bkversion__ = version
#
# /anaconda3/lib/python3.6/site-packages/bokeh/io/notebook.py in push_notebook(document, state, handle)
#     252     events = list(handle.doc._held_events)
#     253     handle.doc._held_events = []
# --> 254     msg = Protocol("1.0").create("PATCH-DOC", events)
#     255
#     256     handle.comms.send(msg.header_json)
#
# /anaconda3/lib/python3.6/site-packages/bokeh/protocol/__init__.py in create(self, msgtype, *args, **kwargs)
#      44         if msgtype not in self._messages:
#      45             raise ProtocolError("Unknown message type %r for protocol version %s" % (msgtype, self._version))
# ---> 46         return self._messages[msgtype].create(*args, **kwargs)
#      47
#      48     def assemble(self, header_json, metadata_json, content_json):
#
# /anaconda3/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py in create(cls, events, use_buffers, **metadata)
#      45
#      46         if not events:
# ---> 47             raise ValueError("PATCH-DOC message requires at least one event")
#      48
#      49         docs = { event.document for event in events }
#
# ValueError: PATCH-DOC message requires at least one event
